# %%
import pandas

# %%
data = pandas.read_excel('/Users/Olamilekan/Downloads/output.xlsx')

compare = pandas.read_csv('/Users/Olamilekan/Downloads/leg.csv')

compare.columns = ['MSISDN', 'SERVICE', 'SERVICE_A', 'SERVICE_B']

# %%
data_50 = data.head(50)
compare_50 = compare.head(50)

# %%
data_t = data[columns]
columns= ['MSISDN','Interest (VAS service)']

compare_t = compare[['MSISDN', 'SERVICE']]

appended_data = pandas.DataFrame(columns=columns)
a = compare_t[compare_t['MSISDN'].isin(data_t['MSISDN'])]
appended_data = pandas.concat([appended_data, a])

# %%
appended_data
# Out:
#   Interest (VAS service)         MSISDN SERVICE
# 0                    NaN  2347062345347     2GO
# 1                    NaN  2348062222076     2GO
# 2                    NaN  2347063650371     2GO
# 3                    NaN  2347034737336     2GO
# 4                    NaN  2347032921160     2GO
# 5                    NaN  2348134494915     2GO

# %%
compare_t = data[['MSISDN', 'SERVICE']]

# %%
compare.head()
# Out:
#           MSISDN SERVICE            SERVICE_A SERVICE_B
# 0  2347062345347     2GO  ISMTN-SOCIAL BUNDLE       NaN
# 1  2348062222076     2GO  ISMTN-SOCIAL BUNDLE       NaN
# 2  2347063650371     2GO  ISMTN-SOCIAL BUNDLE       NaN
# 3  2347034737336     2GO  ISMTN-SOCIAL BUNDLE       NaN
# 4  2347032921160     2GO  ISMTN-SOCIAL BUNDLE       NaN

# %%
data.head()
# Out:
#           MSISDN  Age  Sex  Total Rev (Monthly spend)  Location  \
# 0  2347062345347  NaN  NaN                        NaN       NaN
# 1  2348062222076  NaN  NaN                        NaN       NaN
# 2  2347063650371  NaN  NaN                        NaN       NaN
# 3  2347034737336  NaN  NaN                        NaN       NaN
# 4  2347032921160  NaN  NaN                        NaN       NaN
#
#     Interest (VAS service)  Device OS  Device Brand  CallerFeel (yes or no)  \
# 0                      NaN        NaN           NaN                     NaN
# 1                      NaN        NaN           NaN                     NaN
# 2  mobilezone video-comedy        NaN           NaN                     NaN
# 3                      NaN        NaN           NaN                     NaN
# 4                      NaN        NaN           NaN                     NaN
#
#    Any other data (Monthly data spend, vas, voice etc)  Unnamed: 10
# ...

# %%
p = pandas.read_csv('/Users/Olamilekan/Downloads/append.csv')

# %%
p.head(2)
# Out:
#    Unnamed: 0  Interest (VAS service)         MSISDN       SERVICE
# 0      101002                     NaN  2347030770300   gaming_menu
# 1      119468                     NaN  2348101109430  QriosAcctmgt

# %%
a = p[['MSISDN', 'SERVICE']]

# %%
a.to_csv('append.csv')

# %%
a
# Out:
#              MSISDN                            SERVICE
# 0     2347030770300                        gaming_menu
# 1     2348101109430                       QriosAcctmgt
# 2     2348137604080                         creditMoMo
# 3     2347030770300                        gaming_menu
# 4     2348063301680                   Funmobile_MTNNIG
# 5     2347030770300                        gaming_menu
# 6     2348035789130           CallerFeel weekly 7 days
# 7     2347035061450                       QriosAcctmgt
# 8     2348063301680                   Funmobile_MTNNIG
# 9     2348063451640                          IMIMOBILE
# 10    2347038527800                        Winlot_USSD
# 11    2348101109430                           QriosSMS
# 12    2348036325690                      Vanguard News
# 13    2349032596240                            ACS_SMS
# 14    2347061328390                            ACS_SMS
# 15    2348063451640     Arial View Nigeria Limited_MTN
# ...

# %%
a.shape
# Out:
# (1814, 2)
